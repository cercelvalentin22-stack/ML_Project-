# %% [markdown]
# # AI Live Market Trend Predictor
#
# This notebook runs the live-data version of the project. It downloads updated Yahoo Finance data until the latest available trading day.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(project_root / "src"))

from live_market_ai_project import main
main()
